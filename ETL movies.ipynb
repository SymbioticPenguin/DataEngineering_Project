# %%
import requests
import json
from pprint import pprint
import pandas as pd
from sqlalchemy import create_engine

# %%
url = "http://www.omdbapi.com/?t=" 
api_key = "&apikey=a10836e8"

response = requests.get(url + "Norm of the North: King Sized Adventure" + api_key)
# Converting the response to JSON, and printing the result.
data = response.json()
#pretty print
pprint(data)
# Out:
# {'Actors': 'Alan Marriott, Andrew Toth, Brian Dobson, Cole Howard',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA, India, South Korea, China',
#  'DVD': '11 Jun 2019',
#  'Director': 'Richard Finn, Tim Maltby',
#  'Genre': 'Animation, Adventure, Comedy, Family',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'An ancient Chinese artifact has been stolen by a villainous '
#          'archaeologist named Dexter. With the help of his Lemming friends, '
#          'Norm must keep his word and embark on a journey across the ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNjMwZDhhZWYtOTM0OC00ZTQzLWIyNDktNDM1NmVkYTY4NWNlXkEyXkFqcGdeQXVyNTYyNDUxMDc@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.2/10'}],
#  'Released': '02 Aug 2019',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': 'Norm of the North: King Sized Adventure',
#  'Type': 'movie',
# ...

# %%
#read from csv for netflix_titles and put into a data frame using pandas
csv_file = "Resources/netflix_titles.csv"
netflix_titles_df = pd.read_csv(csv_file)
netflix_titles_df.head()
# Out:
#     show_id     type                                    title  \
# 0  81145628    Movie  Norm of the North: King Sized Adventure
# 1  80117401    Movie               Jandino: Whatever it Takes
# 2  70234439  TV Show                       Transformers Prime
# 3  80058654  TV Show         Transformers: Robots in Disguise
# 4  80125979    Movie                             #realityhigh
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4          Fernando Lebrija
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
# 2  Peter Cullen, Sumalee Montano, Frank Welker, J...
# 3  Will Friedle, Darren Criss, Constance Zimmer, ...
# 4  Nesta Cooper, Kate Walsh, John Michael Higgins...
#
#                                     country         date_added  release_year  \
# ...

# %%
#for loop to get all the data for movies in netflix in the ombdapi
for column in range(10):
    #get movie titles out of dataframe
    column = netflix_titles_df["title"]
#     purl = url + '"' + column + '"' + api_key
    #use OMDB API to get info from movie
#     response = requests.get(purl)
#     #Converting the response to JSON
#     data = response.json()
    
    print(column)
# Out:
# 0           Norm of the North: King Sized Adventure
# 1                        Jandino: Whatever it Takes
# 2                                Transformers Prime
# 3                  Transformers: Robots in Disguise
# 4                                      #realityhigh
#                            ...
# 6229                                   Red vs. Blue
# 6230                                          Maron
# 6231         Little Baby Bum: Nursery Rhyme Friends
# 6232    A Young Doctor's Notebook and Other Stories
# 6233                                        Friends
# Name: title, Length: 6234, dtype: object
# 0           Norm of the North: King Sized Adventure
# 1                        Jandino: Whatever it Takes
# 2                                Transformers Prime
# 3                  Transformers: Robots in Disguise
# 4                                      #realityhigh
#                            ...
# 6229                                   Red vs. Blue
# ...

# %%
purl
# Out:
# 0       http://www.omdbapi.com/?t="Norm of the North: ...
# 1       http://www.omdbapi.com/?t="Jandino: Whatever i...
# 2       http://www.omdbapi.com/?t="Transformers Prime"...
# 3       http://www.omdbapi.com/?t="Transformers: Robot...
# 4       http://www.omdbapi.com/?t="#realityhigh"&apike...
#                               ...
# 6229    http://www.omdbapi.com/?t="Red vs. Blue"&apike...
# 6230    http://www.omdbapi.com/?t="Maron"&apikey=a10836e8
# 6231    http://www.omdbapi.com/?t="Little Baby Bum: Nu...
# 6232    http://www.omdbapi.com/?t="A Young Doctor's No...
# 6233    http://www.omdbapi.com/?t="Friends"&apikey=a10...
# Name: title, Length: 6234, dtype: object
