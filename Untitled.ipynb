# %%
#IMPORT DEPENDENCIES
import sys, requests
import pandas as pd
from pprint import pprint

# Read the Netflix data as a pandas dataframe
data_table = "./Resources/netflix_titles.csv"
netflix_df = pd.read_csv(data_table)


# The user will have to use their own API key when running this code; I pulled our API keys
# in from another file source, shown below
sys.path.insert(1, '/Users/symbioticpenguin/Documents')
from api_keys import comdb, tomdb, tiania_api, tiania_OMDB


# Filtering for movies only
filtered_flix = netflix_df[netflix_df["type"]=="Movie"]

# Filtering for only movies made in the United States
filtered_flix = filtered_flix[netflix_df["country"] == "United States"]

# Dropping all NaN rows
filtered_flix = filtered_flix.dropna()

# limiting to 1000 entries because free api calls only allow 1000 :(
filtered_flix = filtered_flix[:1000]

# LeTs TaKe A lOoK aT tHe DaTa
filtered_flix.head()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   del sys.path[0]
#      show_id   type               title          director  \
# 4   80125979  Movie        #realityhigh  Fernando Lebrija
# 20  80060297  Movie   Manhattan Romance       Tom O'Brien
# 23  70304988  Movie  Stonehearst Asylum     Brad Anderson
# 24  80057700  Movie          The Runner      Austin Stark
# 25  80045922  Movie             6 Years     Hannah Fidell
#
#                                                  cast        country  \
# 4   Nesta Cooper, Kate Walsh, John Michael Higgins...  United States
# 20  Tom O'Brien, Katherine Waterston, Caitlin Fitz...  United States
# 23  Kate Beckinsale, Jim Sturgess, David Thewlis, ...  United States
# 24  Nicolas Cage, Sarah Paulson, Connie Nielsen, W...  United States
# 25  Taissa Farmiga, Ben Rosenfield, Lindsay Burdge...  United States
#
#            date_added  release_year rating duration  \
# 4   September 8, 2017          2017  TV-14   99 min
# 20  September 8, 2017          2014  TV-14   98 min
# 23  September 8, 2017          2014  PG-13  113 min
# 24  September 8, 2017          2015      R   90 min
# 25  September 8, 2015          2015     NR   80 min
#
#                                         listed_in  \
# 4                                        Comedies
# 20  Comedies, Independent Movies, Romantic Movies
# 23                       Horror Movies, Thrillers
# 24                     Dramas, Independent Movies
# 25    Dramas, Independent Movies, Romantic Movies
#
#                                           description
# 4   When nerdy high schooler Dani finally attracts...
# 20  A filmmaker working on a documentary about lov...
# 23  In 1899, a young doctor arrives at an asylum f...
# 24  A New Orleans politician finds his idealistic ...
# 25  As a volatile young couple who have been toget...

# %%
# This is the test code we used before calling the API 1,000 times!

# movie = "t=" + "Finding Nemo"
# key = "&apikey="+comdb
# url = 'http://www.omdbapi.com/?' + movie +  key
# response = requests.get(url).json()

# %%
# This cell contains the for loop to get all the data for movies in netflix in the omdb api

# Creating the list of movie titles to make the API calls on
filtered_movies = filtered_flix['title']

# initializing empty lists to append to in the loop
metascore = []
imdbrating = []
imdbvotes = []
boxoffice = []
title = []

# This is the api call for our OMDB dataframe
for item in filtered_movies:
    
    # If the loop doesn't work, we will skip the API call and list append function.
    try:
        # Creating the string for the URL to call the API from.
        movie = "t=" + item
        key = "&apikey="+tiania_OMDB
        url = 'http://www.omdbapi.com/?' + movie +  key
        
        # Storing the response as a json object
        response = requests.get(url).json()
        
        # Append the items we care about from the json
        boxoffice.append(response['BoxOffice'])
        title.append(response['Title'])
        metascore.append(response["Metascore"])
        imdbrating.append(response['imdbRating'])
        imdbvotes.append(response['imdbVotes'])

    except:
        next

# %%
# Creating the DataFrame for the OMDB data
omdb_df = pd.DataFrame({'title':title,
                        'metascore':metascore,
                        'imdb_rating':imdbrating,
                        'imdb_votes':imdbvotes,
                        'box_office':boxoffice})

# %%
# Joining the two tables: the netflix table and the OMDB table
final_table = filtered_flix.join(omdb_df.set_index('title'),on = 'title', how = 'left')

# %%
# Doing away with the rows that contain "NaN" in any column.
final_table = final_table.dropna()

# %%
final_table
# Out:
#        show_id   type                                title  \
# 20    80060297  Movie                    Manhattan Romance
# 23    70304988  Movie                   Stonehearst Asylum
# 24    80057700  Movie                           The Runner
# 25    80045922  Movie                              6 Years
# 40    80058026  Movie                        Hell and Back
# ...        ...    ...                                  ...
# 3991  80046696  Movie                          Sister Code
# 3998  80241304  Movie                       We the Animals
# 4018  80220013  Movie                                 Heal
# 4020  80065492  Movie  Lego DC Comics: Batman Be-Leaguered
# 4026  80220228  Movie                            Malicious
#
#                         director  \
# 20                   Tom O'Brien
# 23                 Brad Anderson
# 24                  Austin Stark
# 25                 Hannah Fidell
# 40    Tom Gianas, Ross R. Shuman
# ...                          ...
# 3991                 Corey Grant
# 3998              Jeremiah Zagar
# 4018                Kelly Noonan
# 4020                Rick Morales
# 4026             Michael Winnick
#
#                                                    cast        country  \
# 20    Tom O'Brien, Katherine Waterston, Caitlin Fitz...  United States
# 23    Kate Beckinsale, Jim Sturgess, David Thewlis, ...  United States
# 24    Nicolas Cage, Sarah Paulson, Connie Nielsen, W...  United States
# 25    Taissa Farmiga, Ben Rosenfield, Lindsay Burdge...  United States
# 40    Nick Swardson, Mila Kunis, Bob Odenkirk, T.J. ...  United States
# ...                                                 ...            ...
# 3991  Drew Sidora, Eva Marcille, Amber Rose, Marcus ...  United States
# 3998  Evan Rosado, Josiah Gabriel, Isaiah Kristian, ...  United States
# 4018  Kelly Noonan, Deepak Chopra, Michael Beckwith,...  United States
# 4020  Dee Bradley Baker, Troy Baker, John DiMaggio, ...  United States
# 4026  Bojana Novakovic, Josh Stewart, Delroy Lindo, ...  United States
#
#              date_added  release_year rating duration  \
# 20    September 8, 2017          2014  TV-14   98 min
# 23    September 8, 2017          2014  PG-13  113 min
# 24    September 8, 2017          2015      R   90 min
# 25    September 8, 2015          2015     NR   80 min
# 40    September 6, 2018          2015      R   86 min
# ...                 ...           ...    ...      ...
# 3991  February 14, 2016          2015      R   95 min
# 3998  February 11, 2019          2018      R   93 min
# 4018   February 1, 2019          2017  TV-PG  107 min
# 4020   February 1, 2019          2014  TV-Y7   22 min
# 4026   February 1, 2019          2018  TV-MA   91 min
#
#                                              listed_in  \
# 20       Comedies, Independent Movies, Romantic Movies
# 23                            Horror Movies, Thrillers
# 24                          Dramas, Independent Movies
# 25         Dramas, Independent Movies, Romantic Movies
# 40    Action & Adventure, Comedies, Independent Movies
# ...                                                ...
# 3991                 Comedies, Dramas, Romantic Movies
# 3998                        Dramas, Independent Movies
# 4018                                     Documentaries
# 4020                                            Movies
# 4026                                     Horror Movies
#
#                                             description metascore imdb_rating  \
# 20    A filmmaker working on a documentary about lov...       N/A         5.5
# 23    In 1899, a young doctor arrives at an asylum f...        52         6.8
# 24    A New Orleans politician finds his idealistic ...        39         4.7
# 25    As a volatile young couple who have been toget...        53         5.6
# 40    When best friends break a blood oath, one of t...       N/A         5.4
# ...                                                 ...       ...         ...
# 3991  After the death of their beloved mother, three...       N/A         4.5
# 3998  A trio of brothers cope with their parents' vo...        83         6.9
# 4018  Stories from spiritual leaders, physicians and...       N/A         6.8
# 4020  When Superman and the other Justice League sup...       N/A         6.6
# 4026  After receiving a strange present, a professor...       N/A         5.0
#
#      imdb_votes box_office
# 20        1,122        N/A
# 23       48,116        N/A
# 24        4,715        N/A
# 25       10,578        N/A
# 40        4,560   $156,166
# ...         ...        ...
# 3991        318        N/A
# 3998      3,189        N/A
# 4018      1,437        N/A
# 4020        892        N/A
# 4026      2,786        N/A
#
# [859 rows x 16 columns]
